# %%
#melakukan import library yang dibutuhkan
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df =  pd.read_csv('/content/majors.csv')
df
# Out:
#       Unnamed: 0  id_major  id_university        type  \
# 0              0   1111014            111     science
# 1              1   1111022            111     science
# 2              2   1111037            111     science
# 3              3   1111045            111     science
# 4              4   1111053            111     science
# ...          ...       ...            ...         ...
# 3162        3162   9212011            921  humanities
# 3163        3163   9212042            921  humanities
# 3164        3164   9212057            921  humanities
# 3165        3165   9212065            921  humanities
# 3166        3166   9212073            921  humanities
#
#                        major_name  capacity
# 0         PENDIDIKAN DOKTER HEWAN        88
# 1                    TEKNIK SIPIL        64
# 2                    TEKNIK MESIN        48
# 3                    TEKNIK KIMIA        48
# 4                      ARSITEKTUR        48
# ...                           ...       ...
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0      id_major  id_university     capacity
# count  3167.000000  3.167000e+03    3167.000000  3167.000000
# mean   1583.000000  4.216499e+06     421.488791    51.186612
# std     914.378477  2.239755e+06     223.976006    34.911506
# min       0.000000  1.111014e+06     111.000000     6.000000
# 25%     791.500000  3.211170e+06     321.000000    32.000000
# 50%    1583.000000  3.622257e+06     362.000000    44.000000
# 75%    2374.500000  6.121160e+06     612.000000    60.000000
# max    3166.000000  9.212073e+06     921.000000   425.000000

# %%
#memisahkan data type saintek dari data keseluruhan
dapung_saintek = df[df['type']=='science']
dapung_saintek
# Out:
#       Unnamed: 0  id_major  id_university     type  \
# 0              0   1111014            111  science
# 1              1   1111022            111  science
# 2              2   1111037            111  science
# 3              3   1111045            111  science
# 4              4   1111053            111  science
# ...          ...       ...            ...      ...
# 1704        1704   9211313            921  science
# 1705        1705   9211321            921  science
# 1706        1706   9211336            921  science
# 1707        1707   9211344            921  science
# 1708        1708   9211352            921  science
#
#                               major_name  capacity
# 0                PENDIDIKAN DOKTER HEWAN        88
# 1                           TEKNIK SIPIL        64
# 2                           TEKNIK MESIN        48
# 3                           TEKNIK KIMIA        48
# 4                             ARSITEKTUR        48
# ...

# %%
#Visualisasi Data 10 Universitas dengan Daya Tampung Terbanyak Saintek
#Bar Chart

# %%
dapung_soshum = df[df['type']=='humanities']
dapung_soshum
# Out:
#       Unnamed: 0  id_major  id_university        type  \
# 1709        1709   1112017            111  humanities
# 1710        1710   1112025            111  humanities
# 1711        1711   1112033            111  humanities
# 1712        1712   1112041            111  humanities
# 1713        1713   1112056            111  humanities
# ...          ...       ...            ...         ...
# 3162        3162   9212011            921  humanities
# 3163        3163   9212042            921  humanities
# 3164        3164   9212057            921  humanities
# 3165        3165   9212065            921  humanities
# 3166        3166   9212073            921  humanities
#
#                                     major_name  capacity
# 1709                       EKONOMI PEMBANGUNAN        64
# 1710                                 MANAJEMEN        64
# 1711                                 AKUNTANSI        64
# 1712                                ILMU HUKUM       160
# ...

# %%
#Visualisasi Data 10 Universitas dengan Daya Tampung Terbanyak Soshum
#Bar Chart
x = dapung_soshum['id_university']==111
y = dapung_soshum['x'['capacity']]
plt.bar(dapung_soshum['id_university'],
        y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-72a20ab6e55a> in <module>()
#       1 #Visualisasi Data 10 Universitas dengan Daya Tampung Terbanyak Soshum
#       2 #Bar Chart
# ----> 3 x = dapung_soshum['id_university']==111
#       4 y = dapung_soshum['x'['capacity']]
#       5 plt.bar(dapung_soshum['id_university'],
#
# NameError: name 'dapung_soshum' is not defined

# %%
univ = pd.read_csv('/content/universities.csv') #membaca file dataset dalam bentuk csv
univ.head() #menampilkan dataset 5 baris teratas dengan fungsi 'head'
# Out:
#    Unnamed: 0  id_university           university_name
# 0           0            111   UNIVERSITAS SYIAH KUALA
# 1           1            112  UNIVERSITAS MALIKUSSALEH
# 2           2            113    UNIVERSITAS TEUKU UMAR
# 3           3            114       UNIVERSITAS SAMUDRA
# 4           4            115                 ISBI ACEH

# %%
univ.shape
# Out:
# (85, 3)

# %%
#mengetahui letak baris Universitas Indonesia
ui = univ[univ['university_name']== 'UNIVERSITAS INDONESIA']
ui
# Out:
#     Unnamed: 0  id_university        university_name
# 23          23            321  UNIVERSITAS INDONESIA

# %% [markdown]
# Dapat dilihat pada hasil bahwa Universitas Indonesia memiliki kode id_university 321

# %%
#membaca data nilai UTBK saintek tahun 2019
score = pd.read_csv('/content/score_science.csv', sep=',')
score
# Out:
#        Unnamed: 0  id_first_major  id_first_university  id_second_major  \
# 0               0         3321065                  332          3331187
# 1               1         3211015                  321          3611066
# 2               2         3721093                  372          3551302
# 3               3         3321096                  332          3551194
# 4               4         5211104                  521          5211085
# ...           ...             ...                  ...              ...
# 86565       86565         1411161                  141          1421147
# 86566       86566         3561262                  356          3571055
# 86567       86567         3531182                  353          3561022
# 86568       86568         1121094                  112          1221095
# 86569       86569         1911286                  191          1921056
#
#        id_second_university  id_user  score_bio  score_fis  score_kim  \
# ...

# %%
#melihat jumlah kolom dan baris
score.shape
# Out:
# (86570, 14)

# %%
#mengecek baris yang kosong
score_isnull = score.isnull().sum().sort_values(ascending = False)
print(score_isnull)
# Out:
# Unnamed: 0              0
# id_first_major          0
# id_first_university     0
# id_second_major         0
# id_second_university    0
# id_user                 0
# score_bio               0
# score_fis               0
# score_kim               0
# score_kmb               0
# score_kpu               0
# score_kua               0
# score_mat               0
# score_ppu               0
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# id_major          int64
# id_university     int64
# type             object
# major_name       object
# capacity          int64
# dtype: object

# %%
#Visualisasi data untuk Matematika dan Fisika UTBK 2019
import seaborn as sns
sns.set()
plt.figure(figsize=(17, 10))
plt.subplot(2,2,1)
plt.hist(score['score_mat'],
         bins=50,
         facecolor='y',
         alpha=0.80)
plt.grid()
plt.xlabel('Nilai Matematika')
plt.ylabel('Jumlah Peserta')
plt.title('Histogram Sebaran Nilai Matematika')

plt.subplot(2,2,2)
plt.hist(score['score_fis'],
         bins=50,
         facecolor='b',
         alpha=0.75)
plt.grid()
plt.xlabel('Nilai Fisika')
plt.ylabel('Jumlah Peserta')
plt.title('Histogram Sebaran Nilai Fisika')
plt.show()

# %%
#Visualisasi data Kimia dan Biologi UTBK 2019
sns.set()
plt.figure(figsize=(17, 10))
plt.subplot(2,2,1)
plt.hist(score['score_kim'],
         bins=50,
         facecolor='r',
         alpha=0.75)
plt.grid()
plt.xlabel('Nilai Kimia')
plt.ylabel('Jumlah Peserta')
plt.title('Histogram Sebaran Nilai kimia')

plt.subplot(2,2,2)
plt.hist(score['score_bio'],
         bins=50,
         facecolor='g',
         alpha=0.75)
plt.grid()
plt.xlabel('Nilai Biologi')
plt.ylabel('Jumlah Peserta')
plt.title('Histogram Sebaran Nilai Biologi')
plt.show()

# %%
#menyeleksi data khusus Universitas Indonesia
ui_score  = score[score['id_first_university']== 321]
ui_score
# Out:
#        Unnamed: 0  id_first_major  id_first_university  id_second_major  \
# 1               1         3211015                  321          3611066
# 9               9         3211015                  321          7111076
# 12             12         3211313                  321          3211031
# 18             18         3211271                  321          3221087
# 26             26         3211104                  321          3551205
# ...           ...             ...                  ...              ...
# 86395       86395         3211023                  321          7111196
# 86439       86439         3211182                  321          3231101
# 86521       86521         3211023                  321          1711075
# 86524       86524         3211174                  321          3411114
# 86543       86543         3211015                  321          3611066
#
#        id_second_university  id_user  score_bio  score_fis  score_kim  \
# ...

# %%
ui_score.shape
# Out:
# (4410, 14)

# %%
ui_score.describe()
# Out:
#          Unnamed: 0  id_first_major  id_first_university  id_second_major  \
# count   4410.000000    4.410000e+03               4410.0     4.410000e+03
# mean   39248.743084    3.210761e+06                321.0     3.344716e+06
# std    24263.698956    3.926344e+04                  0.0     7.324802e+05
# min        1.000000    1.131057e+06                321.0     1.111014e+06
# 25%    18805.250000    3.211062e+06                321.0     3.211224e+06
# 50%    37665.000000    3.211151e+06                321.0     3.321107e+06
# 75%    59657.250000    3.211224e+06                321.0     3.551186e+06
# max    86543.000000    3.821024e+06                321.0     9.211263e+06
#
#        id_second_university        id_user    score_bio    score_fis  \
# count           4410.000000    4410.000000  4410.000000  4410.000000
# mean             334.573469  162196.463039   569.200454   571.610431
# std               73.268235   92994.480300   106.195964   112.974291
# ...

# %%
#Visualisasi data dengan Scatterplot Universitas Indonesia
plt.scatter(ui_score['score_kmb'], ui_score['score_kpu'])
plt.xlabel('Nilai Kompetensi Memahami Bacaan & Menulis')
plt.ylabel('Nilai Kemampuan Penalaran Umum')
plt.title('Sebaran Nilai KMB dan KPU Universitas Indonesia Pada UTBK 2019')
plt.show()

# %%
plt.scatter(ui_score['score_kua'], ui_score['score_ppu'])
plt.xlabel('Nilai Kemampuan Kuantitatif')
plt.ylabel('Nilai Pengetahuan dan Pemahaman Umum')
plt.title('Sebaran Nilai KUA dan PPU di Universitas Indonesia Pada UTBK 2019')
plt.show()

# %%
#Visualisasi data dengan histogram 
plt.hist(ui_score['score_mat'],
         bins=50,
         facecolor='g',
         alpha=0.75)
plt.xlabel('Nilai Matematika')
plt.ylabel('Jumlah Peserta')
plt.title('Histogram Nilai Matematika di Universitas Indonesia pada UTBK 2019')
plt.text(45, 500, r'$\mu=100,\ \sigma=15$')
plt.grid()
plt.show()

# %%
#Visualisasi data dengan histogram
plt.hist(ui_score['score_fis'],
         bins=50,
         facecolor='g',
         alpha=0.75)
plt.xlabel('Nilai Fisika')
plt.ylabel('Jumlah Peserta')
plt.title('Histogram Nilai Fisika di Universitas Indonesia pada UTBK 2019')
plt.text(45, 500, r'$\mu=100,\ \sigma=15$')
plt.grid()
plt.show()

# %%
#Visualisasi data dengan histogram
plt.hist(ui_score['score_bio'],
         bins=50,
         facecolor='g',
         alpha=0.75)
plt.xlabel('Nilai Biologi')
plt.ylabel('Jumlah Peserta')
plt.title('Histogram Nilai Biologi di Universitas Indonesia pada UTBK 2019')
plt.text(45, 500, r'$\mu=100,\ \sigma=15$')
plt.grid()
plt.show()

# %%
#Visualisasi data dengan histogram
plt.hist(ui_score['score_kim'],
         bins=50,
         facecolor='g',
         alpha=0.75)
plt.xlabel('Nilai Kimia')
plt.ylabel('Jumlah Peserta')
plt.title('Histogram Nilai Kimia di Universitas Indonesia pada UTBK 2019')
plt.text(45, 500, r'$\mu=100,\ \sigma=15$')
plt.grid()
plt.show()

# %%
#import package
import pandas as pd
import numpy as np
import io
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

# %%
#upload file ke google colab
data = files.upload()
# Out:
#      <input type="file" id="files-3e27d634-cb41-4b38-b9e2-fdc578f2cb9e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e27d634-cb41-4b38-b9e2-fdc578f2cb9e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving score_humanities.csv to score_humanities (1).csv

# %%
#read data
df =  pd.read_csv('majors.csv')
df
# Out:
#       Unnamed: 0  id_major  id_university        type  \
# 0              0   1111014            111     science
# 1              1   1111022            111     science
# 2              2   1111037            111     science
# 3              3   1111045            111     science
# 4              4   1111053            111     science
# ...          ...       ...            ...         ...
# 3162        3162   9212011            921  humanities
# 3163        3163   9212042            921  humanities
# 3164        3164   9212057            921  humanities
# 3165        3165   9212065            921  humanities
# 3166        3166   9212073            921  humanities
#
#                        major_name  capacity
# 0         PENDIDIKAN DOKTER HEWAN        88
# 1                    TEKNIK SIPIL        64
# 2                    TEKNIK MESIN        48
# 3                    TEKNIK KIMIA        48
# 4                      ARSITEKTUR        48
# ...                           ...       ...
# ...

# %%
#mengubah data id universitas dari int menjadi string 
df['id_university'] = df['id_university'].apply(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3167 entries, 0 to 3166
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     3167 non-null   int64
#  1   id_major       3167 non-null   int64
#  2   id_university  3167 non-null   object
#  3   type           3167 non-null   object
#  4   major_name     3167 non-null   object
#  5   capacity       3167 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 148.6+ KB

# %%
#data
value = df['type'].value_counts()

#label
label = ['Saintek', 'Soshum']

#plot
fig = plt.figure(figsize =(10, 7))
plt.pie(value, labels = label, autopct='%1.1f%%')
plt.title('Peminat SAINTEK/SOSHUM UTBK 2019')
 
#show plot
plt.show()

# %%
df2 = df.groupby(['id_university','type'], as_index=False)['capacity'].agg('sum')
df3 = df2.sort_values(by=['capacity'], ascending=False )
df3
# Out:
#     id_university        type  capacity
# 90            372     science      3346
# 57            334  humanities      2906
# 130           711     science      2522
# 73            355     science      2420
# 140           731     science      2310
# ..            ...         ...       ...
# 158           921  humanities       128
# 34            172  humanities        99
# 8             115  humanities        72
# 97            382  humanities        68
# 157           913  humanities        53
#
# [160 rows x 3 columns]

# %%
#sortir data berdasarkan tipe ujian
d1 = df3.loc[df3['type'] == 'humanities' ][:10]
d2 = df3.loc[df3['type'] == 'science'][:10]

# %%
#menentukan x dan y 
x = d1['id_university']
y = d1['capacity']

#title dan label
plt.title('10 Kampus dengan daya tampung SOSHUM terbanyak')
plt.xlabel('ID Universitas')
plt.ylabel('Daya Tampung')

plt.bar(x,y)

plt.show()

# %% [markdown]
# 334 = UNIVERSITAS PENDIDIKAN INDONESIA </br>
# 373 = UNIVERSITAS NEGERI MALANG </br>
# 142 = UNIVERSITAS NEGERI PADANG </br>
# 751 = UNIVERSITAS HALUOLEO </br>
# 356 = UNIVERSITAS NEGERI SEMARANG </br>
# 731 = UNIVERSITAS TADULAKO </br>
# 631 = UNIVERSITAS NUSA CENDANA </br>
# 372 = UNIVERSITAS BRAWIJAYA </br>
# 383 = UNIVERSITAS NEGERI SURABAYA </br>
# 712 = UNIVERSITAS NEGERI MAKASSAR </br>

# %%
#menentukan x dan y 
x = d2['id_university']
y = d2['capacity']

#title dan label
plt.title('10 Kampus dengan daya tampung SAINTEK terbanyak')
plt.xlabel('ID Universitas')
plt.ylabel('Daya Tampung')

plt.bar(x,y)

plt.show()

# %% [markdown]
# 372 = UNIVERSITAS BRAWIJAYA </br>
# 711 = UNIVERSITAS HASANUDDIN</br>
# 355 = UNIVERSITAS DIPONEGORO</br>
# 731 = UNIVERSITAS TADULAKO</br>
# 171 = UNIVERSITAS SRIWIJAYA</br>
# 361 = UNIVERSITAS GADJAH MADA</br>
# 192 = INSTITUT TEKNOLOGI SUMATERA</br>
# 371 = UNIVERSITAS JEMBER</br>
# 333 = UNIVERSITAS PADJADJARAN</br>
# 341 = INSTITUT PERTANIAN BOGOR</br>
